# %%
import pandas as pd
raw_data = pd.read_csv('../rodpump_cleaned.csv')
raw_data = pd.DataFrame(raw_data)
raw_data.drop(raw_data[raw_data['contains_imputed'] == 1].index, inplace = True)
raw_data.head()
# Out:
#                    roduid          UWI lifetime_end      FAILURETYPE  \
# 0  GB42ZGOU04727141361583  005-64-9456   2020-02-13           Tubing
# 1  GB07ZEQY22108226742686  008-41-5950   2020-01-31  Sucker Rod Pump
# 2  GB12WDFX96521381421885  008-41-5950   2017-06-29  Sucker Rod Pump
# 5  GB12ZLMZ07727856291157  009-06-3983   2020-02-05  Sucker Rod Pump
# 7  GB91YNOU33103543108327  011-89-6677   2019-12-05             Rods
#
#    H2S_CONCENTRATION  PrimarySetpoint  SecondarySetpoint  StrokeLength  \
# 0                0.0             80.0               65.0    165.878957
# 1                0.0             76.0                0.0    144.000000
# 2                0.0             76.0                0.0    144.000000
# 5                0.0             75.0               60.0    144.000000
# 7                0.0             75.0               60.0    144.000000
#
#      Fillage  YesterdaysAverageSPM  ... overall_max_sideload  \
# ...

# %%
raw_data.to_csv('../rodpump_noImputed.csv',index=False,header=True)
