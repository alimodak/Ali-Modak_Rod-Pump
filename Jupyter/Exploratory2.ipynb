# %% [markdown]
# ### Post-Cleaning EDA

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
raw_data = pd.read_csv('../rodpump_cleaned.csv')

# %% [markdown]
# #### Use seaborn heatmap to identify columns with large numbers of null values
# YesterdaysAverageSPM, AVG_PRESS_FLOWLINE, and all three sideload identifiers have a significant number of missing values

# %%
sns.set(rc={'figure.figsize':(25,15)})
sns.heatmap(raw_data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Iterate over each row to identify correlation between row id and occurance of null values
